# %%
import pandas as pd

from pycaret.regression import *

# %%
df = pd.read_csv('Building Data.csv')

# %%
df
# Out:
#      WallArea  RoofArea  OverallHeight  GlazingArea  HeatingLoad
# 0    0.285714  0.000000            7.0          0.0        15.55
# 1    0.285714  0.000000            7.0          0.0        15.55
# 2    0.285714  0.000000            7.0          0.0        15.55
# 3    0.285714  0.000000            7.0          0.0        15.55
# 4    0.428571  0.111111            7.0          0.0        20.84
# ..        ...       ...            ...          ...          ...
# 763  0.571429  1.000000            3.5          1.0        17.88
# 764  0.714286  1.000000            3.5          1.0        16.54
# 765  0.714286  1.000000            3.5          1.0        16.44
# 766  0.714286  1.000000            3.5          1.0        16.48
# 767  0.714286  1.000000            3.5          1.0        16.64
#
# [768 rows x 5 columns]

# %%
df.shape
# Out:
# (768, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WallArea       768 non-null    float64
#  1   RoofArea       768 non-null    float64
#  2   OverallHeight  768 non-null    float64
#  3   GlazingArea    768 non-null    float64
#  4   HeatingLoad    768 non-null    float64
# dtypes: float64(5)
# memory usage: 30.1 KB

# %%
df.describe()
# Out:
#          WallArea    RoofArea  OverallHeight  GlazingArea  HeatingLoad
# count  768.000000  768.000000      768.00000   768.000000   768.000000
# mean     0.428571    0.601852        5.25000     0.585938    22.307201
# std      0.254382    0.409668        1.75114     0.333051    10.090196
# min      0.000000    0.000000        3.50000     0.000000     6.010000
# 25%      0.285714    0.277778        3.50000     0.250000    12.992500
# 50%      0.428571    0.666667        5.25000     0.625000    18.950000
# 75%      0.571429    1.000000        7.00000     1.000000    31.667500
# max      1.000000    1.000000        7.00000     1.000000    43.100000

# %% [markdown]
# ### Setup the Experiment

# %%
exp = setup(data=df, target= 'HeatingLoad', session_id=123, train_size=0.7, normalize=True)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_67c81f58_bcff_11ea_bce9_3c528213d836row15_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_67c81f58_bcff_11ea_bce9_3c528213d836" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67c81f58_bcff_11ea_bce9_3c528213d836level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_67c81f58_bcff_11ea_bce9_3c528213d836row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_67c81f58_bcff_11ea_bce9_3c528213d836row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_67c81f58_bcff_11ea_bce9_3c528213d836level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_7bf44a92_bcff_11ea_a7f7_3c528213d836 th {
#           text-align: left;
#     }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col0 {
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col4 {
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7bf44a92_bcff_11ea_a7f7_3c528213d836row0_col6 {
#             background-color:  yellow;
# ...

# %% [markdown]
# ### Cat Boosting Regressor  Model

# %%
cat = create_model('catboost')
# Out:
#          MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0     0.3703  0.2592  0.5091  0.9976  0.0221  0.0172
# 1     0.3337  0.1850  0.4301  0.9981  0.0176  0.0155
# 2     0.3238  0.1946  0.4411  0.9980  0.0182  0.0149
# 3     0.3709  0.2317  0.4813  0.9979  0.0181  0.0158
# 4     0.4096  0.3080  0.5550  0.9973  0.0249  0.0173
# 5     0.2848  0.1480  0.3847  0.9982  0.0191  0.0158
# 6     0.4086  0.3116  0.5582  0.9968  0.0263  0.0188
# 7     0.3539  0.2570  0.5070  0.9970  0.0200  0.0163
# 8     0.4064  0.3868  0.6219  0.9960  0.0352  0.0181
# 9     0.2685  0.1344  0.3666  0.9988  0.0143  0.0114
# Mean  0.3531  0.2416  0.4855  0.9976  0.0216  0.0161
# SD    0.0477  0.0753  0.0769  0.0008  0.0057  0.0019

# %%
print(cat)

# %%
plot_model(cat)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Estimator Error): CatBoost estimator is not compatible with plot_model function, try using Catboost with interpret_model instead.

# %%
plot_model(cat, plot = 'error')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Estimator Error): CatBoost estimator is not compatible with plot_model function, try using Catboost with interpret_model instead.

# %%
evaluate_model(cat)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(cat)
# Out:
#                 Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  CatBoost Regressor  0.3359  0.224  0.4732  0.9977  0.0211  0.0161
#          WallArea  RoofArea  GlazingArea  OverallHeight_3.5  HeatingLoad  \
# 0    1.123903e+00  0.972512    -1.009323                1.0        12.85
# 1   -5.619515e-01 -0.655880     0.117363                0.0        29.07
# 2    1.091810e-15  0.972512    -1.760447                1.0         7.18
# 3    5.619515e-01 -0.655880    -1.009323                0.0        35.45
# 4   -5.619515e-01 -1.470077     0.117363                0.0        28.61
# ..            ...       ...          ...                ...          ...
# 226 -1.685854e+00  0.972512    -1.009323                1.0        10.32
# 227  5.619515e-01  0.972512    -1.760447                1.0        10.85
# 228  1.091810e-15 -1.198678    -1.009323                0.0        28.83
# 229 -1.123903e+00  0.972512     1.244049                1.0        12.42
# ...
